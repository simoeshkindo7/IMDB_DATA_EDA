# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('C:\\Users\\dell\\Desktop\\New folder\\imdb_data.csv')

# %%
df = pd.DataFrame(df)

# %%
df.head(3)
# Out:
#    id                              belongs_to_collection    budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1   2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2   3                                                NaN   3300000
#
#                                               genres  \
# 0                     [{'id': 35, 'name': 'Comedy'}]
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                      [{'id': 18, 'name': 'Drama'}]
#
#                             homepage    imdb_id original_language  \
# 0                                NaN  tt2637294                en
# 1                                NaN  tt0368933                en
# 2  http://sonyclassics.com/whiplash/  tt2582802                en
#
#                              original_title  \
# 0                    Hot Tub Time Machine 2
# 1  The Princess Diaries 2: Royal Engagement
# 2                                  Whiplash
#
# ...

# %%
#1. Which movie made the highest profit? Who were its producer and director? Identify the actors in that film.

# %%
df1 = df.copy()
df1['profit'] = df1['revenue'] - df1['budget']
df1.head(1)
# Out:
#    id                              belongs_to_collection    budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
#
#                            genres homepage    imdb_id original_language  \
# 0  [{'id': 35, 'name': 'Comedy'}]      NaN  tt2637294                en
#
#            original_title                                           overview  \
# 0  Hot Tub Time Machine 2  When Lou, who has become the "father of the In...
#
#    popularity  ... runtime                          spoken_languages  \
# 0    6.575393  ...    93.0  [{'iso_639_1': 'en', 'name': 'English'}]
#
#      status                                            tagline  \
# 0  Released  The Laws of Space and Time are About to be Vio...
#
#                     title                                           Keywords  \
# 0  Hot Tub Time Machine 2  [{'id': 4379, 'name': 'time travel'}, {'id': 9...
#
#                                                 cast  \
# ...

# %%
df1['crew'].iloc[0]
# Out:
# '[{\'credit_id\': \'59ac067c92514107af02c8c8\', \'department\': \'Directing\', \'gender\': 0, \'id\': 1449071, \'job\': \'First Assistant Director\', \'name\': \'Kelly Cantley\', \'profile_path\': None}, {\'credit_id\': \'52fe4ee7c3a36847f82afad7\', \'department\': \'Directing\', \'gender\': 2, \'id\': 3227, \'job\': \'Director\', \'name\': \'Steve Pink\', \'profile_path\': \'/myHOgo8mQSCiCAZNGMRdHVr03jr.jpg\'}, {\'credit_id\': \'5524ed25c3a3687ded000d88\', \'department\': \'Writing\', \'gender\': 2, \'id\': 347335, \'job\': \'Writer\', \'name\': \'Josh Heald\', \'profile_path\': \'/pwXJIenrDMrG7t3zNfLvr8w1RGU.jpg\'}, {\'credit_id\': \'5524ed2d925141720c001128\', \'department\': \'Writing\', \'gender\': 2, \'id\': 347335, \'job\': \'Characters\', \'name\': \'Josh Heald\', \'profile_path\': \'/pwXJIenrDMrG7t3zNfLvr8w1RGU.jpg\'}, {\'credit_id\': \'5524ed3d92514166c1004a5d\', \'department\': \'Production\', \'gender\': 2, \'id\': 57822, \'job\': \'Producer\', \'name\': \'Andrew Panay\',
# ...

# %%
def convert_lest(string):
    try:
        return eval(string)
    except:
        return np.nan

# %%
df1['crew'] = df1['crew'].apply(convert_lest)

# %%
df1['crew'].iloc[0]
# Out:
# [{'credit_id': '59ac067c92514107af02c8c8',
#   'department': 'Directing',
#   'gender': 0,
#   'id': 1449071,
#   'job': 'First Assistant Director',
#   'name': 'Kelly Cantley',
#   'profile_path': None},
#  {'credit_id': '52fe4ee7c3a36847f82afad7',
#   'department': 'Directing',
#   'gender': 2,
#   'id': 3227,
#   'job': 'Director',
#   'name': 'Steve Pink',
#   'profile_path': '/myHOgo8mQSCiCAZNGMRdHVr03jr.jpg'},
#  {'credit_id': '5524ed25c3a3687ded000d88',
#   'department': 'Writing',
#   'gender': 2,
#   'id': 347335,
#   'job': 'Writer',
#   'name': 'Josh Heald',
#   'profile_path': '/pwXJIenrDMrG7t3zNfLvr8w1RGU.jpg'},
#  {'credit_id': '5524ed2d925141720c001128',
#   'department': 'Writing',
#   'gender': 2,
#   'id': 347335,
#   'job': 'Characters',
#   'name': 'Josh Heald',
#   'profile_path': '/pwXJIenrDMrG7t3zNfLvr8w1RGU.jpg'},
#  {'credit_id': '5524ed3d92514166c1004a5d',
#   'department': 'Production',
#   'gender': 2,
#   'id': 57822,
#   'job': 'Producer',
# ...

# %%
max_profit = df1['profit'].max()

# %%
df1_profit = df1[df1['profit']==max_profit].reset_index(drop = True)
df1_profit
# Out:
#      id                              belongs_to_collection     budget  \
# 0  1762  [{'id': 9485, 'name': 'The Fast and the Furiou...  190000000
#
#                            genres                  homepage    imdb_id  \
# 0  [{'id': 28, 'name': 'Action'}]  http://www.furious7.com/  tt2820852
#
#   original_language original_title  \
# 0                en      Furious 7
#
#                                             overview  popularity  ... runtime  \
# 0  Deckard Shaw seeks revenge against Dominic Tor...   27.275687  ...   137.0
#
#                            spoken_languages    status              tagline  \
# 0  [{'iso_639_1': 'en', 'name': 'English'}]  Released  Vengeance Hits Home
#
#        title                                           Keywords  \
# 0  Furious 7  [{'id': 830, 'name': 'car race'}, {'id': 3428,...
#
#                                                 cast  \
# 0  [{'cast_id': 17, 'character': 'Dominic Toretto...
#
# ...

# %%
for i in df1_profit['crew'][0]:
    if i['job'] == "Producer" or i["job"] == "Director":
        print(f'{i['job']} : {i['name']}')
# Out:
# Producer : Vin Diesel
# Producer : Neal H. Moritz
# Director : James Wan
# Producer : Michael Fottrell
# Producer : Brandon Birtell

# %%
#2. This data has information about movies made in different languages. Which language has the highest average ROI (return on investment)?

# %%
df1['roi'] = (df1['profit']/df1['budget'])*100
df1.head(1)
# Out:
#    id                              belongs_to_collection    budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
#
#                            genres homepage    imdb_id original_language  \
# 0  [{'id': 35, 'name': 'Comedy'}]      NaN  tt2637294                en
#
#            original_title                                           overview  \
# 0  Hot Tub Time Machine 2  When Lou, who has become the "father of the In...
#
#    popularity  ...                          spoken_languages    status  \
# 0    6.575393  ...  [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                              tagline                   title  \
# 0  The Laws of Space and Time are About to be Vio...  Hot Tub Time Machine 2
#
#                                             Keywords  \
# 0  [{'id': 4379, 'name': 'time travel'}, {'id': 9...
#
#                                                 cast  \
# ...

# %%
df1_roi = df1[df1['roi']!=np.inf]

# %%
df1_roi = df1_roi[['original_language','roi']]

# %%
df1_roi
# Out:
#      original_language          roi
# 0                   en   -12.038207
# 1                   en   137.873588
# 2                   en   296.727273
# 3                   hi  1233.333333
# 5                   en   -59.229525
# ...                ...          ...
# 2992                en     6.888190
# 2993                en   265.695425
# 2997                en    37.625786
# 2998                en   309.436633
# 2999                en   134.534729
#
# [2188 rows x 2 columns]

# %%
df1_roi.groupby('original_language', as_index = False).mean()[['original_language','roi']].sort_values('roi', ascending = False)
# Out:
#    original_language           roi
# 15                ko  3.817941e+07
# 4                 en  5.439874e+05
# 3                 el  5.198013e+03
# 29                tr  9.660000e+02
# 9                 he  4.562925e+02
# 28                te  4.400768e+02
# 2                 de  4.349067e+02
# 32                zh  4.084563e+02
# 6                 fa  4.000000e+02
# 21                pl  3.958170e+02
# 5                 es  3.794217e+02
# 16                ml  3.708333e+02
# 30                ur  3.506738e+02
# 10                hi  2.713313e+02
# 27                ta  2.155159e+02
# 17                mr  1.933333e+02
# 1                 da  1.913964e+02
# 14                ja  1.858405e+02
# 0                 cn  1.738661e+02
# 8                 fr  1.705117e+02
# 24                ru  1.687776e+02
# 20                no  1.480828e+02
# 26                sv  1.148238e+02
# 13                it  7.715555e+01
# 19                nl  3.396170e+01
# 18                nb  1.884794e+01
# ...

# %%
#3. Find out the unique genres of movies in this dataset.

# %%
df2 = df1

# %%
df2[df2['genres'].notna()]['genres']
# Out:
# 0                          [{'id': 35, 'name': 'Comedy'}]
# 1       [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                           [{'id': 18, 'name': 'Drama'}]
# 3       [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4       [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#                               ...
# 2995    [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 2996    [{'id': 18, 'name': 'Drama'}, {'id': 10402, 'n...
# 2997    [{'id': 80, 'name': 'Crime'}, {'id': 28, 'name...
# 2998    [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 2999    [{'id': 53, 'name': 'Thriller'}, {'id': 28, 'n...
# Name: genres, Length: 2993, dtype: object

# %%
df2[~df2['genres'].isnull()]['genres']
# Out:
# 0                          [{'id': 35, 'name': 'Comedy'}]
# 1       [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                           [{'id': 18, 'name': 'Drama'}]
# 3       [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4       [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#                               ...
# 2995    [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 2996    [{'id': 18, 'name': 'Drama'}, {'id': 10402, 'n...
# 2997    [{'id': 80, 'name': 'Crime'}, {'id': 28, 'name...
# 2998    [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 2999    [{'id': 53, 'name': 'Thriller'}, {'id': 28, 'n...
# Name: genres, Length: 2993, dtype: object

# %%
df2['genres'].iloc[0]
# Out:
# "[{'id': 35, 'name': 'Comedy'}]"

# %%
def convert_to_lst(string):
    try:
        return eval(string)
    except:
        return np.nan

# %%
convert_to_lst(np.nan)
# Out:
# nan

# %%
df2['genres']=df2['genres'].apply(convert_to_lst)

# %%
type(df['genres'].iloc[0])
# Out:
# str

# %%
type(df['genres'].iloc[0])
# Out:
# str

# %%
df2
# Out:
#         id                              belongs_to_collection    budget  \
# 0        1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1        2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2        3                                                NaN   3300000
# 3        4                                                NaN   1200000
# 4        5                                                NaN         0
# ...    ...                                                ...       ...
# 2995  2996                                                NaN         0
# 2996  2997                                                NaN         0
# 2997  2998                                                NaN  65000000
# 2998  2999                                                NaN  42000000
# 2999  3000                                                NaN  35000000
#
#                                                  genres  \
# ...

# %%
df2=df2[~df2['genres'].isna()].reset_index(drop=True)

# %%
list_genre=[]

for i in range(len(df2)):
    for j in df2['genres'].iloc[i]:
        print(j)
        list_genre.append(j['name'])
# Out:
# {'id': 35, 'name': 'Comedy'}
# {'id': 35, 'name': 'Comedy'}
# {'id': 18, 'name': 'Drama'}
# {'id': 10751, 'name': 'Family'}
# {'id': 10749, 'name': 'Romance'}
# {'id': 18, 'name': 'Drama'}
# {'id': 53, 'name': 'Thriller'}
# {'id': 18, 'name': 'Drama'}
# {'id': 28, 'name': 'Action'}
# {'id': 53, 'name': 'Thriller'}
# {'id': 16, 'name': 'Animation'}
# {'id': 12, 'name': 'Adventure'}
# {'id': 10751, 'name': 'Family'}
# {'id': 27, 'name': 'Horror'}
# {'id': 53, 'name': 'Thriller'}
# {'id': 99, 'name': 'Documentary'}
# {'id': 28, 'name': 'Action'}
# {'id': 35, 'name': 'Comedy'}
# {'id': 10402, 'name': 'Music'}
# {'id': 10751, 'name': 'Family'}
# {'id': 12, 'name': 'Adventure'}
# {'id': 35, 'name': 'Comedy'}
# {'id': 10402, 'name': 'Music'}
# {'id': 18, 'name': 'Drama'}
# {'id': 35, 'name': 'Comedy'}
# {'id': 18, 'name': 'Drama'}
# {'id': 35, 'name': 'Comedy'}
# {'id': 80, 'name': 'Crime'}
# {'id': 28, 'name': 'Action'}
# {'id': 53, 'name': 'Thriller'}
# ...

# %%
uniques_genres = list(set(list_genre))
pd.Series(uniques_genres)
# Out:
# 0               Crime
# 1             Mystery
# 2              Comedy
# 3               Music
# 4             Western
# 5           Animation
# 6              Family
# 7            Thriller
# 8              Horror
# 9              Action
# 10    Science Fiction
# 11                War
# 12            History
# 13            Romance
# 14           TV Movie
# 15            Foreign
# 16            Fantasy
# 17        Documentary
# 18          Adventure
# 19              Drama
# dtype: object

# %%
pd.DataFrame(uniques_genres, columns = ['Genres'])
# Out:
#              Genres
# 0             Crime
# 1           Mystery
# 2            Comedy
# 3             Music
# 4           Western
# 5         Animation
# 6            Family
# 7          Thriller
# 8            Horror
# 9            Action
# 10  Science Fiction
# 11              War
# 12          History
# 13          Romance
# 14         TV Movie
# 15          Foreign
# 16          Fantasy
# 17      Documentary
# 18        Adventure
# 19            Drama

# %%
#4. Make a table of all the producers and directors of each movie. Find the top 3 producers who have produced movies with the highest average RoI?

# %%
df1['crew'].iloc[1]
# Out:
# [{'credit_id': '52fe43fe9251416c7502563d',
#   'department': 'Directing',
#   'gender': 2,
#   'id': 1201,
#   'job': 'Director',
#   'name': 'Garry Marshall',
#   'profile_path': '/kx77E8p5rnEmKxIhFT0qWCEMEik.jpg'},
#  {'credit_id': '52fe43fe9251416c75025667',
#   'department': 'Camera',
#   'gender': 2,
#   'id': 1214,
#   'job': 'Director of Photography',
#   'name': 'Charles Minsky',
#   'profile_path': None},
#  {'credit_id': '52fe43fe9251416c75025661',
#   'department': 'Sound',
#   'gender': 2,
#   'id': 4500,
#   'job': 'Original Music Composer',
#   'name': 'John Debney',
#   'profile_path': '/hTrlvZlDXQk49nfc2BM9sjKfJv.jpg'},
#  {'credit_id': '52fe43fe9251416c7502564f',
#   'department': 'Production',
#   'gender': 1,
#   'id': 8851,
#   'job': 'Producer',
#   'name': 'Whitney Houston',
#   'profile_path': '/69ouDnXnmklYPr4sMJXWKYz81AL.jpg'},
#  {'credit_id': '52fe43fe9251416c7502566d',
#   'department': 'Editing',
#   'gender': 0,
#   'id': 12970,
#   'job': 'Editor',
# ...

# %%
df2_crew=df1[df1['crew'].notna()]

# %%
def directors_list(dict_prod):
    list_directors=[]

    for i in dict_prod:
        if i['job']=='Director':
            list_directors.append(i['name'])
            
    return list_directors

# %%
def producers_list(dict_prod):
    list_producers=[]

    for i in dict_prod:
        if i['job']=='Producer':
            list_producers.append(i['name'])
            
    return list_producers

# %%
df2_crew['producers_list']=df2_crew['crew'].apply(producers_list)
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_15040\1183741449.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2_crew['producers_list']=df2_crew['crew'].apply(producers_list)

# %%
df2_crew['directors_list']=df2_crew['crew'].apply(directors_list)
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_15040\3580632804.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2_crew['directors_list']=df2_crew['crew'].apply(directors_list)

# %%
df2_crew.head(1)
# Out:
#    id                              belongs_to_collection    budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
#
#                            genres homepage    imdb_id original_language  \
# 0  [{'id': 35, 'name': 'Comedy'}]      NaN  tt2637294                en
#
#            original_title                                           overview  \
# 0  Hot Tub Time Machine 2  When Lou, who has become the "father of the In...
#
#    popularity  ...                                            tagline  \
# 0    6.575393  ...  The Laws of Space and Time are About to be Vio...
#
#                     title                                           Keywords  \
# 0  Hot Tub Time Machine 2  [{'id': 4379, 'name': 'time travel'}, {'id': 9...
#
#                                                 cast  \
# 0  [{'cast_id': 4, 'character': 'Lou', 'credit_id...
#
#                                                 crew   revenue   profit  \
# ...

# %%
df2_crew1=df2_crew[['title','producers_list','directors_list','roi']]

# %%
df2_crew1
# Out:
#                                          title  \
# 0                       Hot Tub Time Machine 2
# 1     The Princess Diaries 2: Royal Engagement
# 2                                     Whiplash
# 3                                      Kahaani
# 4                                   Marine Boy
# ...                                        ...
# 2995                                   Chasers
# 2996                          We Are the Best!
# 2997                   The Long Kiss Goodnight
# 2998                          Along Came Polly
# 2999                                 Abduction
#
#                                          producers_list     directors_list  \
# 0                                        [Andrew Panay]       [Steve Pink]
# 1     [Whitney Houston, Mario Iscovich, Debra Martin...   [Garry Marshall]
# 2     [David Lancaster, Michel Litvak, Jason Blum, H...  [Damien Chazelle]
# 3                                         [Sujoy Ghosh]      [Sujoy Ghosh]
# ...

# %%
df2_crew_roi = df2_crew1[df2_crew1['roi']!=np.inf]

# %%
df2_crew_roi
# Out:
#                                          title  \
# 0                       Hot Tub Time Machine 2
# 1     The Princess Diaries 2: Royal Engagement
# 2                                     Whiplash
# 3                                      Kahaani
# 5       Pinocchio and the Emperor of the Night
# ...                                        ...
# 2992                       The Thief of Bagdad
# 2993                              The Terminal
# 2997                   The Long Kiss Goodnight
# 2998                          Along Came Polly
# 2999                                 Abduction
#
#                                          producers_list      directors_list  \
# 0                                        [Andrew Panay]        [Steve Pink]
# 1     [Whitney Houston, Mario Iscovich, Debra Martin...    [Garry Marshall]
# 2     [David Lancaster, Michel Litvak, Jason Blum, H...   [Damien Chazelle]
# 3                                         [Sujoy Ghosh]       [Sujoy Ghosh]
# ...

# %%
df2_crew_roi.sort_values('roi',ascending=False).reset_index(drop=True).iloc[2:5]
# Out:
#                      title     producers_list         directors_list  \
# 2  The Karate Kid, Part II  [Jerry Weintraub]     [John G. Avildsen]
# 3                Nurse 3-D   [Marc Bienstock]  [Douglas Aarniokoski]
# 4       From Prada to Nada                 []         [Angel Gracia]
#
#             roi
# 2  1.018618e+08
# 3  9.999990e+07
# 4  2.688072e+06

# %%
5. Which actor has acted in the most number of movies? Deep dive into the movies, genres and profits corresponding to this actor.

# %%
df3 = df[df['cast'].notna()].reset_index(drop = True)

# %%
def convert_lest1(string):
    try:
        return eval(string)
    except:
        return (np.nan)

# %%
df3['cast'] = df3['cast'].apply(convert_lest1)

# %%
list_actor = []
for i in range(len(df3)):
    cast_list = df3['cast'].iloc[i]
    for j in cast_list:
        if j['gender']==2:
            list_actor.append(j['name'])

# %%
list_actor
# Out:
# ['Rob Corddry',
#  'Craig Robinson',
#  'Clark Duke',
#  'Adam Scott',
#  'Chevy Chase',
#  'Kumail Nanjiani',
#  'Josh Heald',
#  'Christian Slater',
#  'John Cusack',
#  'Adam Herschman',
#  'Héctor Elizondo',
#  'John Rhys-Davies',
#  'Chris Pine',
#  'Callum Blue',
#  'Larry Miller',
#  'Greg Lewis',
#  'Paul Vogt',
#  'Joseph Leo Bwarie',
#  'Rowan Joseph',
#  'Jeffrey Scott Jensen',
#  'Miles Teller',
#  'J.K. Simmons',
#  'Austin Stowell',
#  'Jayson Blair',
#  'Paul Reiser',
#  'Chris Mulkey',
#  'Damon Gupton',
#  'Max Kasch',
#  'Kofi Siriboe',
#  'Keenan Henson',
#  'Henry G. Sanders',
#  'Stephen Hsu',
#  'Joseph Oliveira',
#  'Nawazuddin Siddiqui',
#  'Darshan Jariwala',
#  'Kim Kang-woo',
#  'Jo Jae-hyeon',
#  'Park Si-yeon',
#  'Kim Joon-bae',
#  'Scott Grimes',
#  'Tom Bosley',
#  'Jeffrey Dean Morgan',
#  'Rob LaBelle',
#  'Quinn Lord',
#  'Jay Brazeau',
#  'John Cassini',
#  'Grant Show',
#  'Tim Perez',
#  'George W. Bush',
#  'Tim Curry',
#  'Kevin Bishop',
# ...

# %%
actors_df=pd.DataFrame(list_actor)

# %%
actors_df.value_counts()
# Out:
# 0
# Samuel L. Jackson       30
# Robert De Niro          30
# Morgan Freeman          27
# Liam Neeson             25
# J.K. Simmons            25
#                         ..
# James Stephens           1
# James Thomas Bligh       1
# James Tyler Robinson     1
# James Urbaniak           1
# Óscar Ladoire           1
# Name: count, Length: 13202, dtype: int64
